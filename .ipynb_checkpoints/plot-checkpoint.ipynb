# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
start = 100
with open('log.pmm0-2.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='SPPMI initialization')
    
with open('log.x0reg0-2.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='BFGD initialization')
plt.legend()
plt.xlabel('iteration$\\times 100$ (step size $1\\times10^{-5}$)')
plt.ylabel('$L_{SGNS}$ with no regularization')
plt.savefig('img/initialization')

# %%
plt.figure()
start = 50
with open('log.x0reg0-1.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='step size $1\\times10^{-5}$')
    
with open('log.x0reg0-2.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='step size $2\\times10^{-5}$')

with open('log.x0reg0-3.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='step size $3\\times10^{-5}$')
plt.legend()
plt.xlabel('iteration$\\times 100$')
plt.ylabel('$L_{SGNS}$ with no regularization')
plt.savefig('img/stepSizes')

# %%
plt.figure()
start = 800
with open('log.x0reg0-1.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='$g=0\cdot\\frac{1}{16}\\|CC^T-WW^T\\|_F$')
    
with open('log.x0reg1-1.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='$g=1\cdot\\frac{1}{16}\\|CC^T-WW^T\\|_F$')

with open('log.x0reg8-1.txt') as file:
    x=[]; y=[]
    for line in file:
        x.append(int(line.split(' ')[2]))
        y.append(float(line.split(' ')[4]))
    plt.plot(x[start:],y[start:], label='$g=8\cdot\\frac{1}{16}\\|CC^T-WW^T\\|_F$ Diverge')
plt.legend()
plt.xlabel('iteration$\\times 100$ (step size $1\\times10^{-5}$)')
plt.ylabel('$f+g$')
plt.savefig('img/regularization')
